# %%
import pandas as pd

# %%
df = pd.read_csv("../data/AdventureWorks_Sales_2015.csv")

# %%
for f in ["../data/AdventureWorks_Products.csv",
          "../data/AdventureWorks_Customers.csv",
          "../data/AdventureWorks_Territories.csv",
          "../data/AdventureWorks_Returns.csv",
          "../data/AdventureWorks_Calendar.csv",
          "../data/AdventureWorks_Product_Categories.csv",
          "../data/AdventureWorks_Product_Subcategories.csv"]:
    df = pd.read_csv(f, encoding="latin1")
    print(f"\n{'='*40}")
    print(f)
    print(df.shape)
    print(df.dtypes)
    print(df.isnull().sum())
# Out:
# ...
# ../data/AdventureWorks_Products.csv
# (293, 11)
# ProductKey                 int64
# ProductSubcategoryKey      int64
# ProductSKU                object
# ProductName               object
# ModelName                 object
# ProductDescription        object
# ProductColor              object
# ProductSize               object
# ProductStyle              object
# ProductCost              float64
# ProductPrice             float64
# dtype: object
# ProductKey                0
# ProductSubcategoryKey     0
# ProductSKU                0
# ProductName               0
# ModelName                 0
# ProductDescription        0
# ProductColor             50
# ProductSize               0
# ProductStyle              0
# ProductCost               0
# ProductPrice              0
# dtype: int64
#
# ...
# ../data/AdventureWorks_Customers.csv
# (18148, 13)
# CustomerKey        int64
# Prefix            object
# FirstName         object
# LastName          object
# BirthDate         object
# ...
